# %%
# %pip install llama-index-llms-openai
# %pip install llama-index-vector-stores-neo4jvector
# %pip install llama-index-embeddings-openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: llama-index-llms-openai in /home/xiaoym/.local/lib/python3.10/site-packages (0.1.18)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.24 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-llms-openai) (0.10.36)
# Requirement already satisfied: pillow>=9.0.0 in /usr/lib/python3/dist-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (9.0.1)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.2.14)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2024.3.1)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.1.19)
# Requirement already satisfied: wrapt in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.16.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (8.3.0)
# Requirement already satisfied: pandas in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.2.2)
# Requirement already satisfied: numpy in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.26.4)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (4.66.4)
# Requirement already satisfied: dataclasses-json in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.6.6)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.8.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.6.0)
# Requirement already satisfied: httpx in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.27.0)
# Requirement already satisfied: networkx>=3.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.3)
# Requirement already satisfied: requests>=2.31.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.31.0)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.0.30)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.6.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (4.11.0)
# Requirement already satisfied: openai>=1.1.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.28.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (6.0.1)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.0.8)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/xiaoym/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/xiaoym/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/xiaoym/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (6.0.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (23.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.9.4)
# Requirement already satisfied: pydantic>=1.10 in /home/xiaoym/.local/lib/python3.10/site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.7.1)
# Requirement already satisfied: httpcore==1.* in /home/xiaoym/.local/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.0.5)
# Requirement already satisfied: sniffio in /home/xiaoym/.local/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: anyio in /home/xiaoym/.local/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (4.3.0)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.3)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2020.6.20)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/xiaoym/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.14.0)
# Requirement already satisfied: joblib in /home/xiaoym/.local/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.4.2)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (8.0.3)
# Requirement already satisfied: regex>=2021.8.3 in /home/xiaoym/.local/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2024.5.10)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/xiaoym/.local/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/xiaoym/.local/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.2.1)
# Requirement already satisfied: greenlet!=0.4.17 in /home/xiaoym/.local/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.21.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/xiaoym/.local/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/xiaoym/.local/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2022.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/xiaoym/.local/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.2.1)
# Requirement already satisfied: packaging>=17.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (24.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /home/xiaoym/.local/lib/python3.10/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.18.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.6.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting llama-index-vector-stores-neo4jvector
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/ef/4a/5f06b3ffa605086d14db155592d70de8af65e8975f7931b3f1ee499c5f46/llama_index_vector_stores_neo4jvector-0.1.4-py3-none-any.whl (6.8 kB)
# Collecting neo4j<6.0.0,>=5.16.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/f9/97/93e1d9a2a7169b819bd9eb71cf703b4c3e26225d042a434ca039282467c4/neo4j-5.20.0.tar.gz (202 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   WARNING: Generating metadata for package neo4j produced metadata for project name unknown. Fix your #egg=neo4j fragments.
# Discarding https://pypi.tuna.tsinghua.edu.cn/packages/f9/97/93e1d9a2a7169b819bd9eb71cf703b4c3e26225d042a434ca039282467c4/neo4j-5.20.0.tar.gz#sha256=c59e54a0c0fa1f109f1d2fa5293c29c2bb30ba388b4f9dd9656919793c10063a (from https://pypi.tuna.tsinghua.edu.cn/simple/neo4j/) (requires-python:>=3.7): Requested unknown from https://pypi.tuna.tsinghua.edu.cn/packages/f9/97/93e1d9a2a7169b819bd9eb71cf703b4c3e26225d042a434ca039282467c4/neo4j-5.20.0.tar.gz#sha256=c59e54a0c0fa1f109f1d2fa5293c29c2bb30ba388b4f9dd9656919793c10063a (from llama-index-vector-stores-neo4jvector) has inconsistent name: filename has 'neo4j', but metadata has 'unknown'
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/21/27/0b1c5f370ef4a1745e4c8dde3e21e8376b76f83864397081538bfc34582a/neo4j-5.16.0.tar.gz (197 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   WARNING: Generating metadata for package neo4j produced metadata for project name unknown. Fix your #egg=neo4j fragments.
# Discarding https://pypi.tuna.tsinghua.edu.cn/packages/21/27/0b1c5f370ef4a1745e4c8dde3e21e8376b76f83864397081538bfc34582a/neo4j-5.16.0.tar.gz#sha256=3d04334f5f99dc06c8150e75f2d608a560789ef35670494ecdcec31c0af276a9 (from https://pypi.tuna.tsinghua.edu.cn/simple/neo4j/) (requires-python:>=3.7): Requested unknown from https://pypi.tuna.tsinghua.edu.cn/packages/21/27/0b1c5f370ef4a1745e4c8dde3e21e8376b76f83864397081538bfc34582a/neo4j-5.16.0.tar.gz#sha256=3d04334f5f99dc06c8150e75f2d608a560789ef35670494ecdcec31c0af276a9 (from llama-index-vector-stores-neo4jvector) has inconsistent name: filename has 'neo4j', but metadata has 'unknown'
# Collecting llama-index-vector-stores-neo4jvector
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/88/23/adf6bf5b26352f6851d8ac39a9ecfbd32982dff807fa26ce7a8b182f9605/llama_index_vector_stores_neo4jvector-0.1.3-py3-none-any.whl (5.6 kB)
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/a9/4d/936f486b1d93876a8d233086e5b42c3cfdca1db7a881f0275001b0ca8492/llama_index_vector_stores_neo4jvector-0.1.2-py3-none-any.whl (5.8 kB)
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/2e/1a/44d2a8be49c81ace94a48f4d7facc32bee05ef61d041645c63ef0dbec908/llama_index_vector_stores_neo4jvector-0.1.1-py3-none-any.whl (5.8 kB)
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/ad/e7/ab874e86d4dd212b888c180ad1c1a659a8d64905b622bc9ac5ac7889b0e3/llama_index_vector_stores_neo4jvector-0.1.0-py3-none-any.whl (5.8 kB)
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/31/02/612cbe6157ba063c32d63fa04b9c0775dc2ac0b300938e85ebf9ed11a04a/llama_index_vector_stores_neo4jvector-0.0.1-py3-none-any.whl (5.6 kB)
# ERROR: Cannot install llama-index-vector-stores-neo4jvector==0.0.1, llama-index-vector-stores-neo4jvector==0.1.0, llama-index-vector-stores-neo4jvector==0.1.1, llama-index-vector-stores-neo4jvector==0.1.2, llama-index-vector-stores-neo4jvector==0.1.3 and llama-index-vector-stores-neo4jvector==0.1.4 because these package versions have conflicting dependencies.
#
# The conflict is caused by:
#     llama-index-vector-stores-neo4jvector 0.1.4 depends on neo4j<6.0.0 and >=5.16.0
#     llama-index-vector-stores-neo4jvector 0.1.3 depends on neo4j<6.0.0 and >=5.16.0
#     llama-index-vector-stores-neo4jvector 0.1.2 depends on neo4j<6.0.0 and >=5.16.0
#     llama-index-vector-stores-neo4jvector 0.1.1 depends on neo4j<6.0.0 and >=5.16.0
#     llama-index-vector-stores-neo4jvector 0.1.0 depends on neo4j<6.0.0 and >=5.16.0
#     llama-index-vector-stores-neo4jvector 0.0.1 depends on neo4j<6.0.0 and >=5.16.0
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip attempt to solve the dependency conflict
#
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: llama-index-embeddings-openai in /home/xiaoym/.local/lib/python3.10/site-packages (0.1.9)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-embeddings-openai) (0.10.36)
# Requirement already satisfied: networkx>=3.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.3)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.0.30)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2024.3.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (8.3.0)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.2.14)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.11.0)
# Requirement already satisfied: pillow>=9.0.0 in /usr/lib/python3/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (9.0.1)
# Requirement already satisfied: httpx in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.27.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.6.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.9.0)
# Requirement already satisfied: numpy in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.26.4)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.8.1)
# Requirement already satisfied: openai>=1.1.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.28.1)
# Requirement already satisfied: wrapt in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.16.0)
# Requirement already satisfied: dataclasses-json in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.6.6)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.9.5)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.6.0)
# Requirement already satisfied: pandas in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.2.2)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.1.19)
# Requirement already satisfied: requests>=2.31.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.31.0)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/xiaoym/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.8)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.9.4)
# Requirement already satisfied: attrs>=17.3.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (23.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/xiaoym/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/xiaoym/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (6.0.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/xiaoym/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.4.1)
# Requirement already satisfied: pydantic>=1.10 in /home/xiaoym/.local/lib/python3.10/site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.7.1)
# Requirement already satisfied: anyio in /home/xiaoym/.local/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.3.0)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.3)
# Requirement already satisfied: httpcore==1.* in /home/xiaoym/.local/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.5)
# Requirement already satisfied: sniffio in /home/xiaoym/.local/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2020.6.20)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/xiaoym/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.14.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/xiaoym/.local/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2024.5.10)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (8.0.3)
# Requirement already satisfied: joblib in /home/xiaoym/.local/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.4.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.7.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/xiaoym/.local/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/xiaoym/.local/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /home/xiaoym/.local/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.21.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/xiaoym/.local/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/xiaoym/.local/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2022.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/xiaoym/.local/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.2.1)
# Requirement already satisfied: packaging>=17.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (24.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/xiaoym/.local/lib/python3.10/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /home/xiaoym/.local/lib/python3.10/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.18.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import openai
from llama_index.vector_stores.neo4jvector import Neo4jVectorStore
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from neo4j import GraphDatabase

# %%
username = "neo4j"
password = "password"
url = "bolt://localhost:7687"
embed_dim = 1536

# %% [markdown]
# 创建索引

# %%
path = ""
neo4j_vector = Neo4jVectorStore(username, password, url, embed_dim)
documents = SimpleDirectoryReader(path).load_data()
from llama_index.core import StorageContext

storage_context = StorageContext.from_defaults(vector_store=neo4j_vector)
index = VectorStoreIndex.from_documents(
    documents, storage_context=storage_context
)

# %%
创建知识图谱索引（与neo4j脱离）

# %%
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import (
    VectorStoreIndex,
    SimpleDirectoryReader,
    KnowledgeGraphIndex,
    Settings
)
from llama_index.graph_stores.neo4j import Neo4jGraphStore

# %%
dir = ""
documents = SimpleDirectoryReader(dir).load_data()
graph_store = Neo4jGraphStore(username=username,password=password,
    url=url,database=database)

storage_context = StorageContext.from_defaults(graph_store=graph_store)

index = KnowledgeGraphIndex.from_documents(documents,
    storage_context=storage_context, max_triplets_per_chunk=2,
    include_embeddings=True
)
